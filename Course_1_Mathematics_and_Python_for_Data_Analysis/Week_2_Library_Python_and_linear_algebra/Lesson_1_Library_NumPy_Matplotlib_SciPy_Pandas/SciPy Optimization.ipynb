# %% [markdown]
# # Решение оптимизационных задач в SciPy

# %%
from scipy import optimize

# %%
def f(x):   # The rosenbrock function
    return .5*(1 - x[0])**2 + (x[1] - x[0]**2)**2
    
print(f([1, 1]))
# Out:
# 0.0

# %%
result = optimize.brute(f, ((-5, 5), (-5, 5)))
print(result)
# Out:
# [ 0.99999324  1.00001283]

# %%
print(optimize.differential_evolution(f, ((-5, 5), (-5, 5))))
# Out:
#      fun: 2.1530351213121061e-21
#  message: 'Optimization terminated successfully.'
#     nfev: 2013
#      nit: 66
#  success: True
#        x: array([ 1.,  1.])

# %%
import numpy as np

def g(x):
        return np.array((-2*.5*(1 - x[0]) - 4*x[0]*(x[1] - x[0]**2), 2*(x[1] - x[0]**2)))

# %%
print(optimize.check_grad(f, g, [2, 2]))
# Out:
# 2.38418579102e-07

# %%
print(optimize.fmin_bfgs(f, [2, 2], fprime=g))
# Out:
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 16
#          Function evaluations: 24
#          Gradient evaluations: 24
# [ 1.00000017  1.00000026]

# %%
print(optimize.minimize(f, [2, 2]))
# Out:
#       fun: 9.536908654831854e-15
#  hess_inv: array([[ 0.9863203 ,  1.97824296],
#        [ 1.97824296,  4.46512252]])
#       jac: array([  4.74153118e-07,  -1.53925014e-07])
#   message: 'Optimization terminated successfully.'
#      nfev: 96
#       nit: 16
#      njev: 24
#    status: 0
#   success: True
#         x: array([ 1.00000007,  1.00000005])

# %%
print(optimize.minimize(f, [2, 2], method='BFGS'))
# Out:
#       fun: 9.536908654831854e-15
#  hess_inv: array([[ 0.9863203 ,  1.97824296],
#        [ 1.97824296,  4.46512252]])
#       jac: array([  4.74153118e-07,  -1.53925014e-07])
#   message: 'Optimization terminated successfully.'
#      nfev: 96
#       nit: 16
#      njev: 24
#    status: 0
#   success: True
#         x: array([ 1.00000007,  1.00000005])

# %%
print(optimize.minimize(f, [2, 2], method='Nelder-Mead'))
# Out:
#  final_simplex: (array([[ 0.99998568,  0.99996682],
#        [ 1.00002149,  1.00004744],
#        [ 1.0000088 ,  1.00003552]]), array([  1.23119954e-10,   2.50768082e-10,   3.59639951e-10]))
#            fun: 1.2311995365407462e-10
#        message: 'Optimization terminated successfully.'
#           nfev: 91
#            nit: 46
#         status: 0
#        success: True
#              x: array([ 0.99998568,  0.99996682])
